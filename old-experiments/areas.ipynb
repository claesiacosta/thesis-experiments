# %%
import pandas as pd
import numpy as np
import os
from IPython.display import JSON
import json
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

import helpers
import api 
gpt = api.GPT(model='gpt-3.5-turbo')

# %%
df = pd.read_csv('all_provas_enem.csv')

# %%
df
# Out:
#        id  year                                            context  \
# 0       1  2013  \nDistribuição espacial atual da população bra...
# 1       2  2013  \nTrata-se de um gigantesco movimento de const...
# 2       3  2013  \nNo dia 1º de julho de 2012, a cidade do Rio ...
# 3       4  2013  TEXTO I\n\nHá  já  algum  tempo  eu  me  aperc...
# 4       5  2013  \nDe  ponta  a  ponta,  é  tudo  praia-palma, ...
# ...   ...   ...                                                ...
# 1929  176  2023  O mastro de uma bandeira foi instalado perpend...
# 1930  177  2023  Um controlador de voo dispõe de um instrumento...
# 1931  178  2023  O calendário maia apresenta duas contagens sim...
# 1932  179  2023  Sejam a, b e c as medidas dos lados de um triâ...
# 1933  180  2023  Entre maratonistas, um parâmetro utilizado é o...
#
#                                                question  \
# 0     \nOs  mapas  representam  distintos  padrões  ...
# ...

# %%
df["area"] = ""
df["cor"] = ""

# %%
df.loc[df.index[(df['year'] == 2023) & (df['id']<=45)]]
# Out:
#       id  year                                            context  \
# 1754   1  2023  No man is an island,\nEntire of itself;\nEvery...
# 1755   2  2023  ## Things We Carry on the Sea\nWe carry tears ...
# 1756   3  2023                                    [[placeholder]]
# 1757   4  2023                                    [[placeholder]]
# 1758   5  2023  (fragmento)\nSpanglish\nTato Laviera\npues est...
# 1759   6  2023  ## Rui Barbosa\nMestre e companheiro, disse eu...
# 1760   7  2023                                    [[placeholder]]
# 1761   8  2023  ## Carta aberta à população brasileira\nPrezad...
# 1762   9  2023  A petição on-line criada por um cidadão paulis...
# 1763  10  2023  A neozelandesa Laurel Hubbard fez história nos...
# 1764  11  2023  “Ganhei 25 medalhas em mundiais, sete em Jogos...
# 1765  12  2023  O acesso às Práticas Corporais/Atividades Físi...
# 1766  13  2023  A indústria do esporte eletrônico é um mercado...
# ...

# %%
df.loc[df.index[(df['year'] == 2023) & (df['id']>=91) & (df['id']<=135)]]
# Out:
#        id  year                                            context  \
# 1844   91  2023  É comum em viagens de avião sermos solicitados...
# 1845   92  2023  ## Terpenos com atividade inseticida: uma alte...
# 1846   93  2023  ## Cafeteria adota copo reutilizável feito com...
# 1847   94  2023  ## Um método simples para avaliar o teor de sa...
# 1848   95  2023  O descarte de detergentes comuns nos esgotos d...
# 1849   96  2023  ## Avaliação de substâncias genotóxicas\n### M...
# 1850   97  2023  O petróleo é uma matéria-prima muito valiosa e...
# 1851   98  2023  O manual de um automóvel alerta sobre os cuida...
# 1852   99  2023  ## Pais com síndrome de Down\n### Três anos ap...
# 1853  100  2023  Para que uma molécula dê origem a um medicamen...
# 1854  101  2023  ## Toxicidade do cianeto\n### Biologia molecul...
# 1855  102  2023  Os cientistas conseguem determinar a idade de ...
# 1856  103  2023  Uma concessionária é responsável por um trecho...
# ...

# %%
# CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS
# CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS
# LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS
# MATEMÁTICA E SUAS TECNOLOGIAS

# %%
df.loc[df.index[(df['year'] == 2013) & (df['id']<=45)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2013) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2013) & (df['id']<=90)],'cor'] = "AZUL"
df.loc[df.index[(df['year'] == 2013) & (df['id']>=91) & (df['id']<=135)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2013) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2013) & (df['id']>=91) & (df['id']<=180)],'cor'] = "AMARELO"


df.loc[df.index[(df['year'] == 2011) & (df['id']<=45)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2011) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2011) & (df['id']<=90)],'cor'] = "AZUL"
df.loc[df.index[(df['year'] == 2011) & (df['id']>=91) & (df['id']<=135)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2011) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2011) & (df['id']>=91) & (df['id']<=180)],'cor'] = "AMARELO"


df.loc[df.index[(df['year'] == 2012) & (df['id']<=45)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2012) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2012) & (df['id']<=90)],'cor'] = "BRANCO"
df.loc[df.index[(df['year'] == 2012) & (df['id']>=91) & (df['id']<=135)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2012) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2012) & (df['id']>=91) & (df['id']<=180)],'cor'] = "AMARELO"


df.loc[df.index[(df['year'] == 2014) & (df['id']<=45)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2014) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2014) & (df['id']<=90)],'cor'] = "AZUL"
df.loc[df.index[(df['year'] == 2014) & (df['id']>=91) & (df['id']<=135)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2014) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2014) & (df['id']>=91) & (df['id']<=180)],'cor'] = "AMARELO"


df.loc[df.index[(df['year'] == 2015) & (df['id']<=45)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2015) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2015) & (df['id']<=90)],'cor'] = "BRANCO"
df.loc[df.index[(df['year'] == 2015) & (df['id']>=91) & (df['id']<=135)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2015) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2015) & (df['id']>=91) & (df['id']<=180)],'cor'] = "CINZA"

df.loc[df.index[(df['year'] == 2009) & (df['id']<=45)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2009) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2009) & (df['id']<=90)],'cor'] = "AZUL"
df.loc[df.index[(df['year'] == 2009) & (df['id']>=91) & (df['id']<=135)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2009) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2009) & (df['id']>=91) & (df['id']<=180)],'cor'] = "AZUL"

df.loc[df.index[(df['year'] == 2010) & (df['id']<=45)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2010) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2010) & (df['id']<=90)],'cor'] = "BRANCO"
df.loc[df.index[(df['year'] == 2010) & (df['id']>=91) & (df['id']<=135)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2010) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2010) & (df['id']>=91) & (df['id']<=180)],'cor'] = "AMARELO"

df.loc[df.index[(df['year'] == 2017) & (df['id']<=45)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2017) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2017) & (df['id']<=90)],'cor'] = "AMARELO"
df.loc[df.index[(df['year'] == 2017) & (df['id']>=91) & (df['id']<=135)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2017) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2017) & (df['id']>=91) & (df['id']<=180)],'cor'] = "AMARELO"

df.loc[df.index[(df['year'] == 2023) & (df['id']<=45)],'area'] = "LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2023) & (df['id']>=46) & (df['id']<=90)],'area'] = "CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2023) & (df['id']<=90)],'cor'] = "LARANJA"
df.loc[df.index[(df['year'] == 2023) & (df['id']>=91) & (df['id']<=135)],'area'] = "CIÊNCIAS DA NATUREZA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2023) & (df['id']>=136) & (df['id']<=180)],'area'] = "MATEMÁTICA E SUAS TECNOLOGIAS"
df.loc[df.index[(df['year'] == 2023) & (df['id']>=91) & (df['id']<=180)],'cor'] = "LARANJA"

# %%
df
# Out:
#        id  year                                            context  \
# 0       1  2013  \nDistribuição espacial atual da população bra...
# 1       2  2013  \nTrata-se de um gigantesco movimento de const...
# 2       3  2013  \nNo dia 1º de julho de 2012, a cidade do Rio ...
# 3       4  2013  TEXTO I\n\nHá  já  algum  tempo  eu  me  aperc...
# 4       5  2013  \nDe  ponta  a  ponta,  é  tudo  praia-palma, ...
# ...   ...   ...                                                ...
# 1929  176  2023  O mastro de uma bandeira foi instalado perpend...
# 1930  177  2023  Um controlador de voo dispõe de um instrumento...
# 1931  178  2023  O calendário maia apresenta duas contagens sim...
# 1932  179  2023  Sejam a, b e c as medidas dos lados de um triâ...
# 1933  180  2023  Entre maratonistas, um parâmetro utilizado é o...
#
#                                                question  \
# 0     \nOs  mapas  representam  distintos  padrões  ...
# ...

# %%
df_all = df.loc[df.index[~(df['year'] == 2016)]]

# %%
df_all
# Out:
#        id  year                                            context  \
# 0       1  2013  \nDistribuição espacial atual da população bra...
# 1       2  2013  \nTrata-se de um gigantesco movimento de const...
# 2       3  2013  \nNo dia 1º de julho de 2012, a cidade do Rio ...
# 3       4  2013  TEXTO I\n\nHá  já  algum  tempo  eu  me  aperc...
# 4       5  2013  \nDe  ponta  a  ponta,  é  tudo  praia-palma, ...
# ...   ...   ...                                                ...
# 1929  176  2023  O mastro de uma bandeira foi instalado perpend...
# 1930  177  2023  Um controlador de voo dispõe de um instrumento...
# 1931  178  2023  O calendário maia apresenta duas contagens sim...
# 1932  179  2023  Sejam a, b e c as medidas dos lados de um triâ...
# 1933  180  2023  Entre maratonistas, um parâmetro utilizado é o...
#
#                                                question  \
# 0     \nOs  mapas  representam  distintos  padrões  ...
# ...

# %%
df_all.to_csv("all_provas_enem_areas.csv", index=False)
